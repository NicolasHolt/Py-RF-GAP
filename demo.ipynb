# %%
from PY_RF_GAP import *
import numpy as np
import matplotlib.pyplot as plt

# %%
datasets = Dataset(seed=123)

# %%
points, labels = datasets.donut()

# %%
plt.scatter(points[:, 0], points[:, 1], c=labels)
plt.show()

# %%
classifier = GAPClassifier().fit(points, labels)

# %%
result = classifier.training_similarity()
